# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from tensorflow.keras import datasets,models,layers
# Adding TF Cifar10 Data ..
from keras.datasets import cifar10
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Normalize the data.
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2,shuffle = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
encoder.fit(Y_train)
Y_train = encoder.transform(Y_train).toarray()
Y_test = encoder.transform(Y_test).toarray()
Y_val =  encoder.transform(Y_val).toarray()
from keras.preprocessing.image import ImageDataGenerator
aug = ImageDataGenerator(horizontal_flip=True, width_shift_range=0.05,
                             height_shift_range=0.05)
aug.fit(X_train)


"""
ResNet-18
Reference:
[1] K. He et al. Deep Residual Learning for Image Recognition. CVPR, 2016
[2] K. He, X. Zhang, S. Ren, and J. Sun. Delving deep into rectifiers:
Surpassing human-level performance on imagenet classification. In
ICCV, 2015.
"""

from keras.callbacks import EarlyStopping
from keras.layers import Dense, Conv2D,  MaxPool2D, Flatten, GlobalAveragePooling2D,  BatchNormalization, Layer, Add
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf


class ResnetBlock(Model):
    """
    A standard resnet block.
    """

    def __init__(self, channels: int, down_sample=False):
        """
        channels: same as number of convolution kernels
        """
        super().__init__()

        self.__channels = channels
        self.__down_sample = down_sample
        self.__strides = [2, 1] if down_sample else [1, 1]

        KERNEL_SIZE = (3, 3)
        # use He initialization, instead of Xavier (a.k.a 'glorot_uniform' in Keras), as suggested in [2]
        INIT_SCHEME = "he_normal"

        self.conv_1 = Conv2D(self.__channels, strides=self.__strides[0],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_1 = BatchNormalization()
        self.conv_2 = Conv2D(self.__channels, strides=self.__strides[1],
                             kernel_size=KERNEL_SIZE, padding="same", kernel_initializer=INIT_SCHEME)
        self.bn_2 = BatchNormalization()
        self.merge = Add()

        if self.__down_sample:
            # perform down sampling using stride of 2, according to [1].
            self.res_conv = Conv2D(
                self.__channels, strides=2, kernel_size=(1, 1), kernel_initializer=INIT_SCHEME, padding="same")
            self.res_bn = BatchNormalization()

    def call(self, inputs):
        res = inputs

        x = self.conv_1(inputs)
        x = self.bn_1(x)
        x = tf.nn.relu(x)
        x = self.conv_2(x)
        x = self.bn_2(x)

        if self.__down_sample:
            res = self.res_conv(res)
            res = self.res_bn(res)

        # if not perform down sample, then add a shortcut directly
        x = self.merge([x, res])
        out = tf.nn.relu(x)
        return out


class ResNet18(Model):

    def __init__(self, num_classes, **kwargs):
        """
            num_classes: number of classes in specific classification task.
        """
        super().__init__(**kwargs)
        self.conv_1 = Conv2D(64, (7, 7), strides=2,
                             padding="same", kernel_initializer="he_normal")
        self.init_bn = BatchNormalization()
        self.pool_2 = MaxPool2D(pool_size=(2, 2), strides=2, padding="same")
        self.res_1_1 = ResnetBlock(64)
        self.res_1_2 = ResnetBlock(64)
        self.res_2_1 = ResnetBlock(128, down_sample=True)
        self.res_2_2 = ResnetBlock(128)
        self.res_3_1 = ResnetBlock(256, down_sample=True)
        self.res_3_2 = ResnetBlock(256)
        self.res_4_1 = ResnetBlock(512, down_sample=True)
        self.res_4_2 = ResnetBlock(512)
        self.avg_pool = GlobalAveragePooling2D()
        self.flat = Flatten()
        self.fc = Dense(num_classes, activation="softmax")

    def call(self, inputs):
        out = self.conv_1(inputs)
        out = self.init_bn(out)
        out = tf.nn.relu(out)
        out = self.pool_2(out)
        for res_block in [self.res_1_1, self.res_1_2, self.res_2_1, self.res_2_2, self.res_3_1, self.res_3_2, self.res_4_1, self.res_4_2]:
            out = res_block(out)
        out = self.avg_pool(out)
        out = self.flat(out)
        out = self.fc(out)
        return out
    

model = ResNet18(10)
model.build(input_shape = (None,32,32,3))
#use categorical_crossentropy since the label is one-hot encoded
from keras.optimizers import SGD
# opt = SGD(learning_rate=0.1,momentum=0.9,decay = 1e-04) #parameters suggested by He [1]
model.compile(optimizer = "adam",loss='categorical_crossentropy', metrics=["accuracy"]) 
model.summary()
from keras.callbacks import EarlyStopping

es = EarlyStopping(patience= 8, restore_best_weights=True, monitor="val_acc")
#I did not use cross validation, so the validate performance is not accurate.
STEPS = len(X_train) / 256
history = model.fit(aug.flow(X_train,Y_train,batch_size = 256), steps_per_epoch=STEPS, batch_size = 256, epochs=30, validation_data=(X_val, Y_val),callbacks=[es])
# Out:
# 2024-05-13 14:13:46.111258: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-13 14:13:46.625162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-05-13 14:13:47.835427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING:tensorflow:AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7fae6db429a0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method ResnetBlock.call of <__main__.ResnetBlock object at 0x7fae6db429a0>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2024-05-13 14:13:47.854581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:47.854807: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:47.857061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:47.857208: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:47.857335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:48.287821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:48.287994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:48.288392: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-13 14:13:48.288581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45727 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:4d:00.0, compute capability: 8.6
# Model: "res_net18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  9472
#
#  batch_normalization (Batch  multiple                  256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  multiple                  0
#  D)
#
#  resnet_block (ResnetBlock)  multiple                  74368
#
#  resnet_block_1 (ResnetBloc  multiple                  74368
#  k)
#
#  resnet_block_2 (ResnetBloc  multiple                  231296
#  k)
#
#  resnet_block_3 (ResnetBloc  multiple                  296192
#  k)
#
#  resnet_block_4 (ResnetBloc  multiple                  921344
#  k)
#
#  resnet_block_5 (ResnetBloc  multiple                  1182208
#  k)
#
#  resnet_block_6 (ResnetBloc  multiple                  3677696
#  k)
#
#  resnet_block_7 (ResnetBloc  multiple                  4723712
#  k)
#
#  global_average_pooling2d (  multiple                  0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  5130
#
# =================================================================
# Total params: 11196042 (42.71 MB)
# Trainable params: 11186442 (42.67 MB)
# Non-trainable params: 9600 (37.50 KB)
# _________________________________________________________________
# Epoch 1/30
# 2024-05-13 14:13:52.460089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-05-13 14:13:53.250229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-05-13 14:13:53.251533: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f9dc0abf270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-13 14:13:53.251546: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-05-13 14:13:53.254612: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-13 14:13:53.350409: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 157/156 [==============================] - ETA: 0s - loss: 1.6165 - accuracy: 0.4345WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 22s 75ms/step - loss: 1.6165 - accuracy: 0.4345 - val_loss: 2.0062 - val_accuracy: 0.2910
# Epoch 2/30
# 157/156 [==============================] - ETA: 0s - loss: 1.2390 - accuracy: 0.5531WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 1.2390 - accuracy: 0.5531 - val_loss: 1.6466 - val_accuracy: 0.4500
# Epoch 3/30
# 157/156 [==============================] - ETA: 0s - loss: 1.0784 - accuracy: 0.6152WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 65ms/step - loss: 1.0784 - accuracy: 0.6152 - val_loss: 1.3037 - val_accuracy: 0.5485
# Epoch 4/30
# 157/156 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.6546WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.9714 - accuracy: 0.6546 - val_loss: 1.1861 - val_accuracy: 0.5920
# Epoch 5/30
# 157/156 [==============================] - ETA: 0s - loss: 0.8750 - accuracy: 0.6904WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.8750 - accuracy: 0.6904 - val_loss: 1.0977 - val_accuracy: 0.6278
# Epoch 6/30
# 157/156 [==============================] - ETA: 0s - loss: 0.8025 - accuracy: 0.7164WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 64ms/step - loss: 0.8025 - accuracy: 0.7164 - val_loss: 0.9811 - val_accuracy: 0.6655
# Epoch 7/30
# 157/156 [==============================] - ETA: 0s - loss: 0.7504 - accuracy: 0.7356WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.7504 - accuracy: 0.7356 - val_loss: 1.0331 - val_accuracy: 0.6428
# Epoch 8/30
# 157/156 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.7559WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.6919 - accuracy: 0.7559 - val_loss: 1.1495 - val_accuracy: 0.6307
# Epoch 9/30
# 157/156 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7700WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.6513 - accuracy: 0.7700 - val_loss: 0.9047 - val_accuracy: 0.7004
# Epoch 10/30
# 157/156 [==============================] - ETA: 0s - loss: 0.6212 - accuracy: 0.7806WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 64ms/step - loss: 0.6212 - accuracy: 0.7806 - val_loss: 0.9220 - val_accuracy: 0.6919
# Epoch 11/30
# 157/156 [==============================] - ETA: 0s - loss: 0.5817 - accuracy: 0.7959WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.5817 - accuracy: 0.7959 - val_loss: 0.9347 - val_accuracy: 0.6953
# Epoch 12/30
# 157/156 [==============================] - ETA: 0s - loss: 0.5431 - accuracy: 0.8066WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.5431 - accuracy: 0.8066 - val_loss: 1.0665 - val_accuracy: 0.6742
# Epoch 13/30
# 157/156 [==============================] - ETA: 0s - loss: 0.5125 - accuracy: 0.8183WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.5125 - accuracy: 0.8183 - val_loss: 1.0337 - val_accuracy: 0.6886
# Epoch 14/30
# 157/156 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.8324WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.4753 - accuracy: 0.8324 - val_loss: 0.9590 - val_accuracy: 0.6983
# Epoch 15/30
# 157/156 [==============================] - ETA: 0s - loss: 0.4529 - accuracy: 0.8407WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 64ms/step - loss: 0.4529 - accuracy: 0.8407 - val_loss: 1.0890 - val_accuracy: 0.6699
# Epoch 16/30
# 157/156 [==============================] - ETA: 0s - loss: 0.4300 - accuracy: 0.8487WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.4300 - accuracy: 0.8487 - val_loss: 1.0775 - val_accuracy: 0.6857
# Epoch 17/30
# 157/156 [==============================] - ETA: 0s - loss: 0.4010 - accuracy: 0.8578WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.4010 - accuracy: 0.8578 - val_loss: 1.0058 - val_accuracy: 0.6915
# Epoch 18/30
# 157/156 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.8629WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.3873 - accuracy: 0.8629 - val_loss: 0.9443 - val_accuracy: 0.7159
# Epoch 19/30
# 157/156 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8709WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.3652 - accuracy: 0.8709 - val_loss: 0.9585 - val_accuracy: 0.7229
# Epoch 20/30
# 157/156 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.8824WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 64ms/step - loss: 0.3331 - accuracy: 0.8824 - val_loss: 0.8912 - val_accuracy: 0.7354
# Epoch 21/30
# 157/156 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8870WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.3207 - accuracy: 0.8870 - val_loss: 1.0242 - val_accuracy: 0.7190
# Epoch 22/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.8971WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2970 - accuracy: 0.8971 - val_loss: 0.8618 - val_accuracy: 0.7474
# Epoch 23/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8968WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2873 - accuracy: 0.8968 - val_loss: 1.0287 - val_accuracy: 0.7125
# Epoch 24/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9086WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2565 - accuracy: 0.9086 - val_loss: 0.9317 - val_accuracy: 0.7414
# Epoch 25/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9035WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2748 - accuracy: 0.9035 - val_loss: 0.8501 - val_accuracy: 0.7544
# Epoch 26/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9165WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2423 - accuracy: 0.9165 - val_loss: 1.0249 - val_accuracy: 0.7364
# Epoch 27/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9201WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 61ms/step - loss: 0.2270 - accuracy: 0.9201 - val_loss: 1.0449 - val_accuracy: 0.7307
# Epoch 28/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9264WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.2095 - accuracy: 0.9264 - val_loss: 0.9817 - val_accuracy: 0.7422
# Epoch 29/30
# 157/156 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9231WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 63ms/step - loss: 0.2169 - accuracy: 0.9231 - val_loss: 0.9664 - val_accuracy: 0.7565
# Epoch 30/30
# 157/156 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9301WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 156/156 [==============================] - 10s 62ms/step - loss: 0.1990 - accuracy: 0.9301 - val_loss: 0.9787 - val_accuracy: 0.7448

# %%
def plotmodelhistory(history): 
    fig, axs = plt.subplots(1,2,figsize=(15,5)) 
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy']) 
    axs[0].plot(history.history['val_accuracy']) 
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy') 
    axs[0].set_xlabel('Epoch')
    
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss']) 
    axs[1].plot(history.history['val_loss']) 
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss') 
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# list all data in history
print(history.history.keys())
plotmodelhistory(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
